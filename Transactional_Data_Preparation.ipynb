# %%
import pandas as pd

# %%
df = pd.read_csv("Cleaned_Shipping_Details.csv")
df.drop(columns=df.columns[0], axis=1,  inplace=True)
df
# Out:
#       Artist Reputation  Height  Width     Weight     Material  \
# 0                  0.26    17.0    6.0     4128.0        Brass
# 1                  0.28     3.0    3.0       61.0        Brass
# 2                  0.07     8.0    5.0      237.0         Clay
# 3                  0.12     9.0    8.0      664.0    Aluminium
# 4                  0.15    17.0    6.0      324.0    Aluminium
# ...                 ...     ...    ...        ...          ...
# 6490               0.37    37.0   10.0    16551.0        Brass
# 6491               0.67    15.0    8.0    18981.0  Material_NA
# 6492               0.68    19.0    8.0      587.0         Clay
# 6493               0.02    33.0    9.0  1269377.0        Stone
# 6494               0.18    30.0   13.0    34729.0        Brass
#
#       Price Of Sculpture  Base Shipping Price International Express Shipment  \
# 0                  13.91                16.27           Yes              Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6495 entries, 0 to 6494
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Artist Reputation      6495 non-null   float64
#  1   Height                 6495 non-null   float64
#  2   Width                  6495 non-null   float64
#  3   Weight                 6495 non-null   float64
#  4   Material               6495 non-null   object
#  5   Price Of Sculpture     6495 non-null   float64
#  6   Base Shipping Price    6495 non-null   float64
#  7   International          6495 non-null   object
#  8   Express Shipment       6495 non-null   object
#  9   Installation Included  6495 non-null   object
#  10  Transport              6495 non-null   object
#  11  Fragile                6495 non-null   object
#  12  Customer Information   6495 non-null   object
#  13  Remote Location        6495 non-null   object
# ...

# %%
# extract specific columns by name,
arm_df = df[["Material", "Transport", "Fragile","Remote Location","Customer Information","Installation Included","International","Express Shipment","state"]]

# %%
arm_df
# Out:
#          Material Transport Fragile Remote Location Customer Information  \
# 0           Brass   Airways      No              No        Working Class
# 1           Brass  Roadways      No              No        Working Class
# 2            Clay  Roadways     Yes             Yes        Working Class
# 3       Aluminium  Roadways      No             Yes              Wealthy
# 4       Aluminium   Airways      No              No        Working Class
# ...           ...       ...     ...             ...                  ...
# 6490        Brass   Airways      No             Yes              Wealthy
# 6491  Material_NA  Roadways      No              No        Working Class
# 6492         Clay  Roadways     Yes              No              Wealthy
# 6493        Stone  Roadways      No             Yes        Working Class
# 6494        Brass   Airways      No              No        Working Class
#
#      Installation Included International Express Shipment state
# ...

# %%
arm_df["Fragile"].value_counts()
# Out:
# No     5457
# Yes    1038
# Name: Fragile, dtype: int64

# %%
# Dictionaries to replace Yes & No with appropriate descriptions
replace_dict_Fragile = {'Yes': 'Fragile', 'No':'Not_Fragile'}
replace_dict_Remote_Location = {'Yes': 'Remote_Location', 'No':'Not_Remote_Location'}
replace_dict_Installation_Included = {'Yes': 'Installation_Included', 'No':'Installation_Not_Included'}
replace_dict_International = {'Yes': 'International_Shipment', 'No':'Not_International_Shipment'}
replace_dict_Express_Shipment = {'Yes': 'Express_Shipment', 'No':'Not_Express_Shipment'}


arm_df["Fragile"] = arm_df["Fragile"].replace(replace_dict_Fragile)
arm_df["Remote Location"] = arm_df["Remote Location"].replace(replace_dict_Remote_Location)
arm_df["Installation Included"] = arm_df["Installation Included"].replace(replace_dict_Installation_Included)
arm_df["International"] = arm_df["International"].replace(replace_dict_International)
arm_df["Express Shipment"] = arm_df["Express Shipment"].replace(replace_dict_Express_Shipment)
# Out:
# /var/folders/t7/1gj7tf5j31l_rj3z115b_ty80000gn/T/ipykernel_47266/226130973.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arm_df["Fragile"] = arm_df["Fragile"].replace(replace_dict_Fragile)
# /var/folders/t7/1gj7tf5j31l_rj3z115b_ty80000gn/T/ipykernel_47266/226130973.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arm_df["Remote Location"] = arm_df["Remote Location"].replace(replace_dict_Remote_Location)
# ...

# %%
arm_df
# Out:
#          Material Transport      Fragile      Remote Location  \
# 0           Brass   Airways  Not_Fragile  Not_Remote_Location
# 1           Brass  Roadways  Not_Fragile  Not_Remote_Location
# 2            Clay  Roadways      Fragile      Remote_Location
# 3       Aluminium  Roadways  Not_Fragile      Remote_Location
# 4       Aluminium   Airways  Not_Fragile  Not_Remote_Location
# ...           ...       ...          ...                  ...
# 6490        Brass   Airways  Not_Fragile      Remote_Location
# 6491  Material_NA  Roadways  Not_Fragile  Not_Remote_Location
# 6492         Clay  Roadways      Fragile  Not_Remote_Location
# 6493        Stone  Roadways  Not_Fragile      Remote_Location
# 6494        Brass   Airways  Not_Fragile  Not_Remote_Location
#
#      Customer Information      Installation Included  \
# 0           Working Class  Installation_Not_Included
# 1           Working Class  Installation_Not_Included
# 2           Working Class  Installation_Not_Included
# ...

# %%
transactions_list = arm_df.values.tolist()

# %%
transactions_list
# Out:
# [['Brass',
#   'Airways',
#   'Not_Fragile',
#   'Not_Remote_Location',
#   'Working Class',
#   'Installation_Not_Included',
#   'International_Shipment',
#   'Express_Shipment',
#   'OH'],
#  ['Brass',
#   'Roadways',
#   'Not_Fragile',
#   'Not_Remote_Location',
#   'Working Class',
#   'Installation_Not_Included',
#   'Not_International_Shipment',
#   'Not_Express_Shipment',
#   'WY'],
#  ['Clay',
#   'Roadways',
#   'Fragile',
#   'Remote_Location',
#   'Working Class',
#   'Installation_Not_Included',
#   'Not_International_Shipment',
#   'Not_Express_Shipment',
#   'WA'],
#  ['Aluminium',
#   'Roadways',
#   'Not_Fragile',
#   'Remote_Location',
#   'Wealthy',
#   'Installation_Not_Included',
#   'Not_International_Shipment',
#   'Not_Express_Shipment',
#   'KY'],
#  ['Aluminium',
#   'Airways',
#   'Not_Fragile',
#   'Not_Remote_Location',
#   'Working Class',
#   'Installation_Included',
#   'International_Shipment',
#   'Express_Shipment',
#   'PA'],
#  ['Wood',
# ...

# %%
import csv

# Save transaction list as CSV file
with open('transactions.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(transactions_list)
